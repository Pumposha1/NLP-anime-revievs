# %%
import pandas as pd

path = "Data_.csv"  # у тебя файл в корне проекта, значит так ок

def read_csv_smart(p):
    encodings = ["utf-8", "utf-8-sig", "cp1251"]
    seps = [",", ";", "\t"]
    last_err = None

    for enc in encodings:
        for sep in seps:
            try:
                df = pd.read_csv(p, encoding=enc, sep=sep)
                # если прочиталось "в одну колонку", значит разделитель не тот
                if df.shape[1] == 1:
                    continue
                return df, enc, sep
            except Exception as e:
                last_err = e

    raise RuntimeError(f"Не получилось прочитать CSV. Последняя ошибка: {last_err}")

df, enc, sep = read_csv_smart(path)
print("OK! encoding =", enc, "sep =", repr(sep))
print("shape =", df.shape)
display(df.head(5))
print("columns =", list(df.columns))
